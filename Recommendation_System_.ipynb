# %%
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.12/dist-packages (1.1.5)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from scikit-surprise) (1.5.3)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-surprise) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-surprise) (1.16.3)

# %%
from surprise import Dataset
data = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to /root/.surprise_data/ml-100k

# %%
# Step 1: Install
# !pip install scikit-surprise

# Step 2: Imports
from surprise import Dataset, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy

# Step 3: Load MovieLens 100K automatically (no file needed)
data = Dataset.load_builtin('ml-100k')

# Step 4: Split into train and test
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Step 5: Train SVD model (matrix factorization)
model = SVD(n_factors=50, random_state=42)
model.fit(trainset)

# Step 6: Evaluate
predictions = model.test(testset)
print("RMSE:", accuracy.rmse(predictions))
print("MAE:", accuracy.mae(predictions))

# Step 7: Show top 5 recommendations for user ID 1
from collections import defaultdict

def get_top_n(predictions, n=5):
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]
    return top_n

top_n = get_top_n(predictions, n=5)
print("\nTop 5 recommended movie IDs for User 1:", top_n['1'])
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.12/dist-packages (1.1.5)
# Requirement already satisfied: joblib>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from scikit-surprise) (1.5.3)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-surprise) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-surprise) (1.16.3)
# RMSE: 0.9348
# RMSE: 0.934761145254825
# MAE:  0.7377
# MAE: 0.7376926362573809
#
# Top 5 recommended movie IDs for User 1: [('183', np.float64(4.458448062175493)), ('182', np.float64(4.4347401675766855)), ('98', np.float64(4.421104485445599)), ('170', np.float64(4.393633164939887)), ('134', np.float64(4.319456984806828))]
